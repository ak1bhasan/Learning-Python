# %%
print("In the name of Allah")
# Out:
# In the name of Allah

# %%
# The Blackjack Capstone Project

import random

logo = r"""
 _     _            _    _            _    
| |   | |          | |  (_)          | |   
| |__ | | __ _  ___| | ___  __ _  ___| | __
| '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
| |_) | | (_| | (__|   <| | (_| | (__|   < 
|_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
                       _/ |                
                      |__/                           
"""

win = r"""
 __   __           __        ___       _ 
 \ \ / /__  _   _  \ \      / (_)_ __ | |
  \ V / _ \| | | |  \ \ /\ / /| | '_ \| |
   | | (_) | |_| |   \ V  V / | | | | |_|
   |_|\___/ \__,_|    \_/\_/  |_|_| |_(_)
"""

lose = r"""
 __   __            _                   _ 
 \ \ / /__  _   _  | |    ___  ___  ___| |
  \ V / _ \| | | | | |   / _ \/ __|/ _ \ |
   | | (_) | |_| | | |__| (_) \__ \  __/_|
   |_|\___/ \__,_| |_____\___/|___/\___(_)
"""

draw = r"""
  ____  ____      ___        ___ _ 
 |  _ \|  _ \    / \ \      / / | |
 | | | | |_) |  / _ \ \ /\ / /| | |
 | |_| |  _ <  / ___ \ V  V / |_|_|
 |____/|_| \_\/_/   \_\_/\_/  (_|_)
"""


def deal_card():
    """Returns a random card from the deck"""
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
    card = random.choice(cards)
    return card

def calculate_score(cards):
    """Take a list of cards and return the score calculated from the cards"""
    if sum(cards) == 21 and len(cards) == 2:
        return 0

    if 11 in cards and sum(cards) > 21:
        cards.remove(11)
        cards.append(1)

    return sum(cards)

def compare(u_score, c_score):
    if u_score == c_score:
        print(draw)
        return "Draw"
    elif c_score == 0:
        print(lose)
        return "Lose, Opponent has Blackjack."
    elif u_score == 0:
        print(win)
        return "Win with a Blackjack."
    elif u_score > 21:
        print(lose)
        return "You went over, You lose."
    elif c_score > 21:
        print(win)
        return "Opponent went over, You win"
    elif u_score > c_score:
        print(win)
        return "You win"
    else:
        print(lose)
        return "You lose"

def play_game():
    print(logo)
    user_cards = []
    computer_cards = []
    computer_score = -1
    user_score = -1
    is_game_over = False

    for _ in range(2):
        user_cards.append(deal_card())
        computer_cards.append(deal_card())

    # print(user_cards)
    # print(computer_cards)

    while not is_game_over:
        user_score = calculate_score(user_cards)
        computer_score = calculate_score(computer_cards)

        print(f"Your cards: {user_cards}, current score: {user_score}")
        print(f"Computer's first card: {computer_cards[0]}")

        if user_score == 0 or computer_score == 0 or user_score > 21:
            is_game_over = True
        else:
            user_should_deal = input("Type 'y' to get another card, type 'n' to pass: ")
            if user_should_deal == 'y':
                user_cards.append(deal_card())
            else:
                is_game_over = True


    while computer_score != 0 and computer_score < 17:
        computer_cards.append(deal_card())
        computer_score = calculate_score(computer_cards)

    print(f"Your final hand: {user_cards}, final score: {user_score}")
    print(f"Computer's final hand: {computer_cards}, final score: {computer_score}")
    print(compare(user_score, computer_score))

while input("Do you want to play a game of Blackjack? Type 'y' or 'n': ") == "y":
    print("\n" * 20)
    play_game()
# Out:
# Do you want to play a game of Blackjack? Type 'y' or 'n':  y
#  _     _            _    _            _
# | |   | |          | |  (_)          | |
# | |__ | | __ _  ___| | ___  __ _  ___| | __
# | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# | |_) | | (_| | (__|   <| | (_| | (__|   <
# |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#                        _/ |
#                       |__/
#
# Your cards: [6, 5], current score: 11
# Computer's first card: 2
# Type 'y' to get another card, type 'n' to pass:  y
# Your cards: [6, 5, 4], current score: 15
# Computer's first card: 2
# Type 'y' to get another card, type 'n' to pass:  n
# Your final hand: [6, 5, 4], final score: 15
# Computer's final hand: [2, 10, 9], final score: 21
#
#  __   __            _                   _
#  \ \ / /__  _   _  | |    ___  ___  ___| |
#   \ V / _ \| | | | | |   / _ \/ __|/ _ \ |
#    | | (_) | |_| | | |__| (_) \__ \  __/_|
#    |_|\___/ \__,_| |_____\___/|___/\___(_)
#
# You lose
# Do you want to play a game of Blackjack? Type 'y' or 'n':  y
#  _     _            _    _            _
# | |   | |          | |  (_)          | |
# | |__ | | __ _  ___| | ___  __ _  ___| | __
# | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# | |_) | | (_| | (__|   <| | (_| | (__|   <
# |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#                        _/ |
#                       |__/
#
# Your cards: [11, 1], current score: 12
# Computer's first card: 3
# Type 'y' to get another card, type 'n' to pass:  y
# Your cards: [1, 10, 1], current score: 12
# Computer's first card: 3
# Type 'y' to get another card, type 'n' to pass:  y
# Your cards: [1, 10, 1, 6], current score: 18
# Computer's first card: 3
# Type 'y' to get another card, type 'n' to pass:  n
# Your final hand: [1, 10, 1, 6], final score: 18
# Computer's final hand: [3, 8, 1, 4, 7], final score: 23
#
#  __   __           __        ___       _
#  \ \ / /__  _   _  \ \      / (_)_ __ | |
#   \ V / _ \| | | |  \ \ /\ / /| | '_ \| |
#    | | (_) | |_| |   \ V  V / | | | | |_|
#    |_|\___/ \__,_|    \_/\_/  |_|_| |_(_)
#
# Opponent went over, You win
# Do you want to play a game of Blackjack? Type 'y' or 'n':  y
#  _     _            _    _            _
# | |   | |          | |  (_)          | |
# | |__ | | __ _  ___| | ___  __ _  ___| | __
# | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# | |_) | | (_| | (__|   <| | (_| | (__|   <
# |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#                        _/ |
#                       |__/
#
# Your cards: [11, 1], current score: 12
# Computer's first card: 3
# Type 'y' to get another card, type 'n' to pass:  y
# Your cards: [11, 1, 2], current score: 14
# Computer's first card: 3
# Type 'y' to get another card, type 'n' to pass:  y
# Your cards: [11, 1, 2, 5], current score: 19
# Computer's first card: 3
# Type 'y' to get another card, type 'n' to pass:  y
# Your cards: [1, 2, 5, 5, 1], current score: 14
# Computer's first card: 3
# Type 'y' to get another card, type 'n' to pass:  y
# Your cards: [1, 2, 5, 5, 1, 1], current score: 15
# Computer's first card: 3
# Type 'y' to get another card, type 'n' to pass:  y
# Your cards: [1, 2, 5, 5, 1, 1, 6], current score: 21
# Computer's first card: 3
# Type 'y' to get another card, type 'n' to pass:  n
# Your final hand: [1, 2, 5, 5, 1, 1, 6], final score: 21
# Computer's final hand: [3, 9, 9], final score: 21
#
#   ____  ____      ___        ___ _
#  |  _ \|  _ \    / \ \      / / | |
#  | | | | |_) |  / _ \ \ /\ / /| | |
#  | |_| |  _ <  / ___ \ V  V / |_|_|
#  |____/|_| \_\/_/   \_\_/\_/  (_|_)
#
# Draw
# Do you want to play a game of Blackjack? Type 'y' or 'n':  n
