# %%
print("In the name of Allah")
# Out:
# In the name of Allah

# %%
# Python Dictionary

programming_dictionary = {
    "Bug": "An error in a program that prevents the program from running as expected.",
    "Function": "A piece of code that you can easily call over and over again.",
}

print(programming_dictionary["Bug"])

programming_dictionary["loop"] = "The action of doing something over and over again."

print(programming_dictionary)

empty_dictionary = {}
print(empty_dictionary)

# Edit an item in a dictionary

programming_dictionary["Bug"] = "A moth in your dictionary"
print(programming_dictionary)

# Loop through a dictionary

for key in programming_dictionary:
    print(key)
    print(programming_dictionary[key])

# Wipe an existing dictionary

programming_dictionary = {}
print(programming_dictionary)
# Out:
# An error in a program that prevents the program from running as expected.
# {'Bug': 'An error in a program that prevents the program from running as expected.', 'Function': 'A piece of code that you can easily call over and over again.', 'loop': 'The action of doing something over and over again.'}
# {}
# {'Bug': 'A moth in your dictionary', 'Function': 'A piece of code that you can easily call over and over again.', 'loop': 'The action of doing something over and over again.'}
# Bug
# A moth in your dictionary
# Function
# A piece of code that you can easily call over and over again.
# loop
# The action of doing something over and over again.
# {}

# %% [markdown]
# Grading Program
# You have access to a database of student_scores in the format of a dictionary. The keys in student_scores are the names of the students and the values are their exam scores.
#
#
#
# Write a program that converts their scores to grades.
#
#
#
# By the end of your program, you should have a new dictionary called student_grades that should contain student names as keys and their assessed grades for values.
#
#
#
# The final version of the student_grades dictionary will be checked.
#
#
#
# **DO NOT** modify lines 1-7 to change the existing student_scores dictionary.
#
#
#
# This is the scoring criteria:
#
# - Scores 91 - 100: Grade = "Outstanding"
#
# - Scores 81 - 90: Grade = "Exceeds Expectations"
#
# - Scores 71 - 80: Grade = "Acceptable"
#
# - Scores 70 or lower: Grade = "Fail"

# %%
student_scores = {
    'Harry': 88,
    'Ron': 78,
    'Hermione': 95,
    'Draco': 75,
    'Neville': 60
}

student_grades = {}

for key in student_scores:
    if 91 <= student_scores[key] <= 100:
        student_grades[key] = "Outstanding"
    elif 81 <= student_scores[key] <= 90:
        student_grades[key] = "Exceeds Expectations"
    elif 71 <= student_scores[key] <= 80:
        student_grades[key] = "Acceptable"
    else:
        student_grades[key] = "Fail"
    
print(student_grades)
# Out:
# {'Harry': 'Exceeds Expectations', 'Ron': 'Acceptable', 'Hermione': 'Outstanding', 'Draco': 'Acceptable', 'Neville': 'Fail'}

# %%
# Nesting Lists and Dictionaries

captials = {
    "France" : "Paris",
    "Germany" : "Berlin",
}

# Nested List in Dictionary

travel_log = {
    "France" : ["Paris", "Lille", "Dijon"],
    "Germany" : ["Sttutgart", "Berlin"],
}

print(travel_log["France"][1])

nested_list = ["A", "B", ["C", "D"]]
print(nested_list[2])
print(nested_list[2][1])
# Out:
# Lille
# ['C', 'D']
# D

# %%
travel_log = {
    "France" : {
        "cities_visited" : ["Paris", "Lille", "Dijon"],
        "total_visits" : 12
    },
    "Germany" : {
        "cities_visited" : ["Berlin", "Hamburg", "Sttutgart"],
        "total_visits" : 5
    },
}

# print(travel_log["France"]["cities_visited"][1])

print(travel_log["Germany"])
print(travel_log["Germany"]["cities_visited"])
print(travel_log["Germany"]["cities_visited"][2])
# Out:
# {'cities_visited': ['Berlin', 'Hamburg', 'Sttutgart'], 'total_visits': 5}
# ['Berlin', 'Hamburg', 'Sttutgart']
# Sttutgart

# %%
print("Hello")
print("\n" * 100)
name = input("Type something")
print(name)
# Out:
# Hello
# Type something akib
# akib

# %%
logo = '''
                         ___________
                         \\         /
                          )_______(
                          |"""""""|_.-._,.---------.,_.-._
                          |       | | |               | | ''-.
                          |       |_| |_             _| |_..-'
                          |_______| '-' `'---------'` '-'
                          )"""""""(
                         /_________\\
                       .-------------.
                      /_______________\\
'''


print(logo)

def find_highest_bidder( bidding_dictionary ):
    winner = ""
    highest_bid = 0;
    for bidder in bidding_dictionary:
        bid_amount = bidding_dictionary[bidder]
        if bid_amount > highest_bid:
            highest_bid = bid_amount
            winner = bidder
    # winner = max( bidding_dictionary, key = bidding_dictionary.get )
    # highest_bid = bidding_dictionary[winner]

    print(f"The winner is {winner} with a bid of $ {highest_bid}.")

bids = {}

continue_bidding = True
while continue_bidding:
    name = input("What is your name?:  ")
    price = int(input("What is your bid?: $ "))
    bids[name] = price
    should_continue = input("Are there any other bidders? Type 'yes' or 'no'.\n").lower()

    if should_continue == "no":
        continue_bidding = False
        find_highest_bidder(bids)
    elif should_continue == "yes":
        print("\n" * 30)
# Out:
#                          ___________
#                          \         /
#                           )_______(
#                           |"""""""|_.-._,.---------.,_.-._
#                           |       | | |               | | ''-.
#                           |       |_| |_             _| |_..-'
#                           |_______| '-' `'---------'` '-'
#                           )"""""""(
#                          /_________\
#                        .-------------.
#                       /_______________\
# What is your name?:   Akib
# What is your bid?: $  15
# Are there any other bidders? Type 'yes' or 'no'.
#  yes
# What is your name?:   Jax
# What is your bid?: $  10
# Are there any other bidders? Type 'yes' or 'no'.
#  yes
# What is your name?:   Tom
# What is your bid?: $  9
# Are there any other bidders? Type 'yes' or 'no'.
#  no
# The winner is Akib with a bid of $ 15.
