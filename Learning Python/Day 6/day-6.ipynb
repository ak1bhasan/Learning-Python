# %%
print("I begin in the name of Allah.")
# Out:
# I begin in the name of Allah.

# %%
# Functions, Code Blocks and While Loops

print("Hello World")
num_char = len("Hello")
print(num_char)

def my_function():
    print("Hello")
    print("Everyone")

my_function()
# Out:
# Hello World
# 5
# Hello
# Everyone

# %%
# Identation

# %%
# While loop
