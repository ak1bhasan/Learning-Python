# %%
water_level = 50
if water_level > 80:
    print("Drain water")
else:
    print("Continue")
# Out:
# Continue

# %%
print("Welcome to the rollercoaster!")
height = int(input("What is tyout height in cm? "))

if height >= 120:
    print("You can ride the rollercoasster")
else:
    print("Sorry you have to groow taller before you can ride.")
# Out:
# Welcome to the rollercoaster!
# What is tyout height in cm?  120
# You can ride the rollercoasster

# %%
# Modulo
number_to_check = int(input("What is the number you want to check?"))

print(number_to_check % 2)

if number_to_check % 2 == 0:
    print("Even")
else: 
    print("Odd")
# Out:
# What is the number you want to check? 12
# 0
# Even

# %%
print("Welcome to the rollercoaster!")
height = int(input("What is tyout height in cm? "))

if height >= 120:
    print("You can ride the rollercoasster")
    age = int(input("What is your age? "))
    if age <= 12:
        print("Please pay $5.")
    elif age <= 18:
        print("Please pay $7.")
    else:
        print("Please pay $12.")
else:
    print("Sorry you have to groow taller before you can ride.")
# Out:
# Welcome to the rollercoaster!
# What is tyout height in cm?  120
# You can ride the rollercoasster
# What is your age?  5
# Please pay $5.

# %%
print("Welcome to the rollercoaster!")
height = int(input("What is tyout height in cm? "))
bill = 0;

if height >= 120:
    print("You can ride the rollercoasster")
    age = int(input("What is your age? "))
    if age <= 12:
        bill = 5
        print("Child tickets are $5.")
    elif age <= 18:
        bill = 7
        print("Youth tickets are $7.")
    else:
        bill = 12
        print("Adults tickets are $12.")

    wants_photo = input("Do you want to have a photo to take? Type y for Yes and n for No.")
    if wants_photo == "y":
        # add $3 to their bill
        bill += 3
        
    print(f"Your final bill is {bill}")

else:
    print("Sorry you have to groow taller before you can ride.")
# Out:
# Welcome to the rollercoaster!
# What is tyout height in cm?  180
# You can ride the rollercoasster
# What is your age?  21
# Adults tickets are $12.
# Do you want to have a photo to take? Type y for Yes and n for No. y
# Your final bill is 15

# %%
# Pizza Delivery Program

size = input("What size pizza do you want? S, M or L: ")
pepperoni = input("Do you want pepperoni on your pizza? Y or N: ")
extra_cheese = input("Do you want extra cheese? Y or N: ")

total = 0

if size == "S":
    total += 15
elif size == "M":
    total += 20
elif size == "L":
    total += 25
else:
    print("You typed the wrong inputs.")

if pepperoni == "Y":
    if size == "S":
        total += 2
    else:
        total += 3

if extra_cheese == "Y":
    total += 1

print(f"Your final bill: ${total}")
# Out:
# What size pizza do you want? S, M or L:  M
# Do you want pepperoni on your pizza? Y or N:  Y
# Do you want extra cheese? Y or N:  N
# Your final bill: $23

# %%
# Logical Operators


print("Welcome to the rollercoaster!")
height = int(input("What is tyout height in cm? "))
bill = 0;

if height >= 120:
    print("You can ride the rollercoasster")
    age = int(input("What is your age? "))
    if age <= 12:
        bill = 5
        print("Child tickets are $5.")
    elif age <= 18:
        bill = 7
        print("Youth tickets are $7.")
    # elif age >= 45 and age <= 55:
    elif 45 <= age <= 55:
        bill = 0;
    else:
        bill = 12
        print("Adults tickets are $12.")

    wants_photo = input("Do you want to have a photo to take? Type y for Yes and n for No.")
    if wants_photo == "y":
        # add $3 to their bill
        bill += 3
        
    print(f"Your final bill is {bill}")

else:
    print("Sorry you have to groow taller before you can ride.")
# Out:
# Welcome to the rollercoaster!
# What is tyout height in cm?  180
# You can ride the rollercoasster
# What is your age?  45
# Do you want to have a photo to take? Type y for Yes and n for No. n
# Your final bill is 0

# %%
# Treasure Island

print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/[TomekK]
*******************************************************************************
''')
print("Welcome to my Treasure Island.")
print("Your misssion is to find the treasure.")
choice1 = input('You\'re at a cross road, where do you want to go? Type "left" or "right".\n').lower()

if choice1 == "left":
    choice2 = input('You\'re come to a lake, there is an island in the middle of the lake. Type "wait" to wait for a boat. Type "swim" to swim across\n').lower()
    if choice2 == "wait":
        choice3 = input("You arrive at the island unharmed. There is house with 3 doors. One red, one yellow, and one blue. Which colour do you choose?\n").lower()
        if choice3 == "red":
            print("It's a room with full fire. Game Over.")
        elif choice3 == "yellow": 
            print("You've found the treasure. You win!")
        elif choice3 == "blue":
            print("You enter a room of beasts. Game Over.")
        else:
            print("You choose a door that doesn't exist. Game over.")
    else:
        print("You got attacked by an angry trout. Game Over.")

else:
    print("You fell in to a hole. Game over.")
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# |___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
# ...
